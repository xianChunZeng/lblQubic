# %% [markdown]
# # Make sure the switch box setting connect the ZCU216 to the quantum chip
# Switchs wiring diagram can be found at: <br>
# https://docs.google.com/document/d/19PCMW-sWQP9IDaH1ihExrhLNKL3zvspGWfvfol0w36c/edit#
#
# X4Y2: <br> switchbox.switchset('http://192.168.1.204','AB')
#
# X4Y1: <br>
# switchbox.switchset('http://192.168.1.204','BD')<br>
# switchbox.switchset('http://192.168.1.215','CD')

# %%
switchbox.switchset('http://192.168.1.204','AB')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 switchbox.switchset('http://192.168.1.204','AB')
#
# NameError: name 'switchbox' is not defined

# %%
#%matplotlib widget #need this for click GUIs
import qubic.toolchain as tc
import qubic.rpc_client as rc
import qubitconfig.qchip as qc
from distproc.hwconfig import FPGAConfig, load_channel_configs
import numpy as np
import matplotlib.pyplot as plt
from chipcalibration import rabi
from importlib import reload
import qubic.state_disc as sd
import chipcalibration.config as cfg

# %%
fpga_config = FPGAConfig(**{'fpga_clk_period': 2.e-9, 'alu_instr_clks': 5, 'jump_cond_clks': 5, 'jump_fproc_clks': 5, 'pulse_regwrite_clks': 3})

qchipname = 'X4Y2'
fpga_config, qchip, channel_config = cfg.load_configs(qchipname)
chanmap = {'Q0':7,'Q2':1,'Q1':4,'Q3':3,'Q4':5,'Q5':6,'Q6':2}

# %%
runner = rc.CircuitRunnerClient(ip='192.168.1.247')

# %%
reload(rabi)
drvqubit=['Q3']
readqubits = ['Q3'] #['Q0', 'Q1', 'Q2', 'Q3', 'Q4']
nwidth = 140
pulse_widths = np.linspace(4.e-9, 140*4.e-9, nwidth)
i_rabi = rabi.Rabi(drvqubit=drvqubit, readqubits=readqubits,
                   pulse_widths=pulse_widths, qchip=qchip, 
                   fpga_config=fpga_config, channel_configs=channel_config)
# Out:
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling

# %%
i_rabi.run(runner, 100)
# Out:
# ---------------------------------------------------------------------------
# Fault                                     Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 i_rabi.run(runner, 100)
#
# File ~/chipcalibration/chipcalibration/rabi.py:64, in Rabi.run(self, circuit_runner, nsamples)
#      50 reads_per_shot = 1
#      51 #nshot = min(ACC_BUFSIZE//reads_per_shot,nsamples)
#      52 #navg = int(np.ceil(nsamples/nshot))
#      53 #self.s11 = {chan: np.zeros((len(self.pulse_widths), nshot*navg), dtype=np.complex128)
#    (...)
#      62 #    for chan, iqdata in shots.items():
#      63 #        self.s11[chan][i] = iqdata #np.reshape(iqdata, (nshot*navg, len(self.pulse_widths))).T
# ---> 64 self.s11 = circuit_runner.run_circuit_batch(self.raw_asm_progs, nsamples, 1, delay_per_shot=5000.e-6)
#      65 self._fit_gmm()
#
# File ~/qubic_software/qubic/rpc_client.py:87, in CircuitRunnerClient.run_circuit_batch(self, raw_asm_list, n_total_shots, reads_per_shot, delay_per_shot, reload_cmd, reload_freq, reload_env, zero_between_reload)
#      49 def run_circuit_batch(self, raw_asm_list, n_total_shots, reads_per_shot=1, delay_per_shot=500.e-6,
#      50                       reload_cmd=True, reload_freq=True, reload_env=True, zero_between_reload=True):
#      51     """
#      52     Runs a batch of circuits given by a list of raw_asm "binaries". Each circuit is run n_total_shots
#      53     times. reads_per_shot, n_total_shots, and delay_per_shot are passed directly into run_circuit, and must
#    (...)
#      84             shape (len(raw_asm_list), n_total_shots, reads_per_shot)
#      85     """
# ---> 87     s11 = self.proxy.run_circuit_batch(raw_asm_list, n_total_shots, reads_per_shot, float(delay_per_shot),
#      88                                  reload_cmd, reload_freq, reload_env, zero_between_reload, True)
#      89     for ch in s11.keys():
#      90         s11[ch] = np.reshape(np.frombuffer(s11[ch].data, dtype=np.complex128),
#      91                              (len(raw_asm_list), n_total_shots, reads_per_shot))
#
# File ~/anaconda3/envs/qubic2/lib/python3.11/xmlrpc/client.py:1122, in _Method.__call__(self, *args)
#    1121 def __call__(self, *args):
# -> 1122     return self.__send(self.__name, args)
#
# File ~/anaconda3/envs/qubic2/lib/python3.11/xmlrpc/client.py:1464, in ServerProxy.__request(self, methodname, params)
#    1458 def __request(self, methodname, params):
#    1459     # call a method on the remote server
#    1461     request = dumps(params, methodname, encoding=self.__encoding,
#    1462                     allow_none=self.__allow_none).encode(self.__encoding, 'xmlcharrefreplace')
# -> 1464     response = self.__transport.request(
#    1465         self.__host,
#    1466         self.__handler,
#    1467         request,
#    1468         verbose=self.__verbose
#    1469         )
#    1471     if len(response) == 1:
#    1472         response = response[0]
#
# File ~/anaconda3/envs/qubic2/lib/python3.11/xmlrpc/client.py:1166, in Transport.request(self, host, handler, request_body, verbose)
#    1164 for i in (0, 1):
#    1165     try:
# -> 1166         return self.single_request(host, handler, request_body, verbose)
#    1167     except http.client.RemoteDisconnected:
#    1168         if i:
#
# File ~/anaconda3/envs/qubic2/lib/python3.11/xmlrpc/client.py:1182, in Transport.single_request(self, host, handler, request_body, verbose)
#    1180     if resp.status == 200:
#    1181         self.verbose = verbose
# -> 1182         return self.parse_response(resp)
#    1184 except Fault:
#    1185     raise
#
# File ~/anaconda3/envs/qubic2/lib/python3.11/xmlrpc/client.py:1354, in Transport.parse_response(self, response)
#    1351     stream.close()
#    1352 p.close()
# -> 1354 return u.close()
#
# File ~/anaconda3/envs/qubic2/lib/python3.11/xmlrpc/client.py:668, in Unmarshaller.close(self)
#     666     raise ResponseError()
#     667 if self._type == "fault":
# --> 668     raise Fault(**self._stack[0])
#     669 return tuple(self._stack)
#
# Fault: <Fault 1: "<class 'KeyError'>:'7'">

# %%
compiled_rabi = tc.run_compile_stage(i_rabi.circuits, fpga_config, qchip)
# Out:
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling
# done resolving block
# done z-resolving block
# done resolving block
# done z-resolving block
# done scheduling

# %%
compiled_rabi[1].program
# Out:
# {('Q3.qdrv', 'Q3.rdrv', 'Q3.rdlo'): [{'op': 'phase_reset'},
#   {'op': 'pulse',
#    'freq': 5125000000,
#    'phase': 0.0,
#    'amp': 0.32479386965778895,
#    'env': {'env_func': 'cos_edge_square',
#     'paradict': {'ramp_fraction': 0.25, 'twidth': 8e-09}},
#    'start_time': 200005,
#    'dest': 'Q3.qdrv'},
#   {'op': 'pulse',
#    'freq': 6700437825.423339,
#    'phase': 0.0,
#    'amp': 0.017906057102356918,
#    'env': {'env_func': 'cos_edge_square',
#     'paradict': {'ramp_fraction': 0.25, 'twidth': 4e-06}},
#    'start_time': 200009,
#    'dest': 'Q3.rdrv'},
#   {'op': 'pulse',
#    'freq': 6700437825.423339,
#    'phase': 3.0363641695072783,
#    'amp': 1.0,
#    'env': {'env_func': 'square',
#     'paradict': {'phase': 0.0, 'amplitude': 1.0, 'twidth': 4e-06}},
#    'start_time': 200309,
#    'dest': 'Q3.rdlo'},
#   {'op': 'done_stb'}]}

# %%
debug
# Out:
# > /usr/local/share/pynq-venv/lib/python3.10/site-packages/ipykernel/kernelbase.py(1219)_input_request()
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# ipdb> q

# %%
i_rabi.circuits
# Out:
# [[{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4e-09}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 8e-09}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 1.2000000000000002e-08}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 1.6e-08}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 2e-08}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 2.4e-08}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 2.8000000000000003e-08}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 3.2e-08}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 3.6000000000000005e-08}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 4.000000000000001e-08}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 4.4000000000000004e-08}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 4.8000000000000006e-08}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 5.200000000000001e-08}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 5.6000000000000005e-08}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 6.000000000000001e-08}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 6.4e-08}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 6.8e-08}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 7.2e-08}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 7.6e-08}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 8e-08}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 8.4e-08}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 8.800000000000001e-08}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 9.2e-08}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 9.6e-08}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 1.0000000000000001e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 1.04e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 1.08e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 1.12e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 1.16e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 1.2000000000000002e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 1.2400000000000003e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 1.28e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 1.3200000000000002e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 1.3600000000000003e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 1.4e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 1.4400000000000002e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 1.4800000000000003e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 1.52e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 1.5600000000000002e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 1.6000000000000003e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 1.64e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 1.6800000000000002e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 1.7200000000000003e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 1.7600000000000001e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 1.8000000000000002e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 1.8400000000000003e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 1.8800000000000002e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 1.9200000000000003e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 1.9600000000000003e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 2.0000000000000002e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 2.0400000000000003e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 2.08e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 2.1200000000000002e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 2.1600000000000003e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 2.2e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 2.2400000000000002e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 2.2800000000000003e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 2.32e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 2.3600000000000002e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 2.4000000000000003e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 2.44e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 2.48e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 2.52e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 2.56e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 2.6e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 2.64e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 2.68e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 2.72e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 2.76e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 2.8e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 2.84e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 2.88e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 2.92e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 2.96e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 3e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 3.04e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 3.08e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 3.12e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 3.16e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 3.2e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 3.24e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 3.28e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 3.32e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 3.36e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 3.4000000000000003e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 3.44e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 3.48e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 3.5200000000000003e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 3.56e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 3.6e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 3.6400000000000003e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 3.68e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 3.72e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 3.7600000000000003e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 3.8e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 3.84e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 3.8800000000000003e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 3.92e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 3.96e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4.04e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4.08e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4.12e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4.16e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4.2e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4.24e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4.28e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4.32e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4.36e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4.4e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4.44e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4.48e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4.52e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4.56e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4.6e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4.64e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4.68e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4.72e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 4.7600000000000003e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 4.800000000000001e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4.84e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4.88e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4.92e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 4.96e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 5e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 5.040000000000001e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 5.08e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 5.12e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 5.16e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 5.2e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 5.24e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 5.28e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 5.32e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 5.36e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 5.4e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 5.44e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 5.48e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 5.52e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi',
#    'qubit': ['Q1'],
#    'modi': {(0, 'twidth'): 5.560000000000001e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}],
#  [{'name': 'delay', 't': 0.0004},
#   {'name': 'rabi', 'qubit': ['Q1'], 'modi': {(0, 'twidth'): 5.6e-07}},
#   {'name': 'read', 'qubit': ['Q0']},
#   {'name': 'read', 'qubit': ['Q1']},
#   {'name': 'read', 'qubit': ['Q2']},
#   {'name': 'read', 'qubit': ['Q3']},
#   {'name': 'read', 'qubit': ['Q4']}]]

# %%
print(i_rabi.ones_frac)
print(i_rabi.zeros_frac)
# Out:
# {'Q0': array([ 86,  91, 112,  75,  77,  95,  95,  66, 108,  66,  89,  85,  74,
#         74,  63,  57,  46,  76,  65,  69,  58,  62,  70,  62,  83,  50,
#         48,  37,  37,  56,  35,  46,  48,  42,  42,  37,  48,  44,  42,
#         41,  41,  41,  44,  33,  45,  42,  45,  45,  42,  56,  44,  46,
#         28,  43,  47,  63,  43,  51,  47,  40,  67,  57,  41,  51,  60,
#         43,  42,  44,  48,  30,  66,  46,  51,  46,  51,  40,  45,  45,
#         57,  44,  55,  58,  47,  47,  41,  55,  44,  45,  58,  50,  51,
#         44,  52,  50,  60,  53,  43,  64,  45,  47,  73,  45,  43,  49,
#         50,  56,  53,  54,  63,  58,  51,  56,  44,  37,  37,  48,  40,
#         55,  73,  68,  50,  57,  56,  53,  62,  56,  65,  64,  64,  64,
#         64,  64,  64,  64,  64,  64,  64,  64,  64,  64]), 'Q1': array([67, 70, 70, 41, 66, 63, 77, 43, 89, 41, 75, 57, 55, 62, 51, 39, 39,
#        52, 38, 46, 41, 48, 50, 38, 53, 38, 38, 24, 29, 33, 28, 39, 36, 32,
#        37, 29, 30, 35, 27, 25, 30, 28, 31, 28, 35, 24, 32, 29, 26, 41, 36,
#        32, 20, 34, 36, 45, 40, 40, 28, 33, 46, 32, 34, 37, 35, 24, 35, 37,
#        36, 25, 38, 29, 38, 21, 40, 28, 25, 28, 40, 25, 39, 38, 33, 29, 32,
#        41, 30, 34, 44, 34, 31, 26, 35, 36, 44, 37, 26, 47, 29, 34, 47, 30,
#        39, 23, 29, 43, 32, 40, 40, 45, 35, 35, 40, 30, 21, 32, 29, 40, 36,
#        39, 34, 46, 27, 31, 37, 50, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49,
#        49, 49, 49, 49]), 'Q2': array([  7,  13,   9,  20,  36,  49,  55,  88,  62, 103,  95,  95, 104,
#         95,  88,  86,  83,  45,  36,  30,  19,   8,   8,   6,   8,  18,
#         29,  52,  70,  82,  94, 110, 120, 131, 130, 139, 116, 109, 106,
#         85,  73,  45,  46,  26,   8,   7,   7,  11,  18,  30,  41,  45,
#         86,  91, 110,  94, 116, 128, 126, 120, 103,  77,  92,  74,  63,
#        152, 162, 160, 143, 163, 151, 149, 156, 156, 162, 151, 155, 157,
#        157, 158, 159, 156, 166, 154, 157, 155, 154, 158, 143, 156, 153,
#        173, 155, 153, 135, 156, 148, 154, 160, 131, 140, 158, 148, 140,
#        158, 158, 155, 152, 169, 135, 153, 149, 155, 148, 160, 152, 155,
#        143, 156, 145, 141, 150, 152, 159, 144, 154, 153, 141, 149, 149,
#        155, 148, 149, 139, 147, 157, 136, 153, 154, 127, 153, 153, 149,
#        150, 143, 145, 145, 135, 140, 149, 144, 156, 163, 163, 150, 157,
#        141, 125, 132, 148, 140, 144, 146, 138, 143, 134, 135, 135, 135,
#        135, 135, 135, 135, 135, 135, 135, 135, 135, 135])}

# %%
plt.plot(i_rabi.ones_frac['Q3'])

# %%
plt.plot(np.real(i_rabi.s11[3].flatten()), np.imag(i_rabi.s11[3].flatten()), '.')

# %%
i_rabi.s11[1].shape
# Out:
# (140, 100, 1)

# %%
np.zeros((3,4)).shape
# Out:
# (3, 4)

# %%
debug
# Out:
# > /home/xilinx/software/qubic/state_disc.py(106)set_labels_maxtomin()
#     104             if isinstance(chan, str): #iq_shot_dict is indexed by qubit
#     105                 result = self.gmm_dict[chan].predict(iq_shots)
# --> 106                 if output_keys == 'qubit':
#     107                     result_dict[chan] = result
#     108                 elif output_keys == 'channel':
#
# ipdb> result
# *** NameError: name 'result' is not defined
# ipdb> q

# %%
i_rabi.s11
# Out:
# {2: array([-7455010. +556331.j, -3852551.-2619945.j, -3012646.-1468984.j, ...,
#         -1956156.-1949457.j, -2817337.-1680015.j, -1871286.-1502131.j]),
#  4: array([-2476289.+2107168.j,  1500060. +967335.j, -2378779.-1926234.j, ...,
#         -1629420.-2289513.j, -1381087.-2234042.j, -1810679.-1969196.j]),
#  1: array([ -436402.+5172281.j,   694643.+2967200.j, -2028462.-2392060.j, ...,
#         -1122191.+1183144.j,  1236526.+3790050.j,  -366951.+2096431.j]),
#  3: array([ 1445299.+7647849.j, -1324437.+1900527.j,  -167153. +376026.j, ...,
#         -1310700.+3305294.j,  -567708.+3538473.j,    56152.+2582544.j]),
#  5: array([68651625.-61283167.j, -2728502.   +91304.j, -3622123. +1681065.j,
#         ..., -3525538.  +227718.j, -2761361. +4210469.j,
#         -2545626. +1736525.j])}

# %%
i_rabi.readout_chanmap
# Out:
# {'Q0': 2, 'Q1': 4, 'Q2': 1, 'Q3': 3, 'Q4': 5}

# %%
reload(sd)
gmm = sd.GMMManager(chanmap_or_chan_cfgs=channel_config)

# %%
gmm.fit(chevron.s11)

# %%
result = gmm.predict(chevron.s11)

# %%
gmm.set_labels_maxtomin({chan: shots[0].flatten() 
                                      for chan, shots in chevron.s11.items()}, [0, 1])

# %%
state_disc_shots = gmm.predict(chevron.s11)

# %%
ones_frac = {qubit: np.sum(state_disc_shots[qubit], axis=2) for qubit in state_disc_shots.keys()}

# %%
plt.pcolormesh(ones_frac['Q1'])
